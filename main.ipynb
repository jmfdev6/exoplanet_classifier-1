# %%
import pandas as pd
import numpy as np

# %%
print('Loading dataframe...')
df = pd.read_csv('data/TOI_2025.10.04_05.29.58.csv', comment='#', on_bad_lines='skip')
df=df.drop(columns=['toi_created','rowupdate'])
print('Dataframe loaded successfully!', end='\n\n')

print('Dataframe shape:', df.shape, end='\n\n')

print('Dataframe preview:')
display(df.head())
display(df.info()) # Summary of the dataframe
display(df.describe()) # Statistical summary of numerical columns
display(df.isnull().sum()) # Count of missing values per column
# Out:
# Loading dataframe...
# Dataframe loaded successfully!
#
# Dataframe shape: (7703, 21)
#
# Dataframe preview:
#        toi        tid tfopwg_disp         rastr          ra         decstr  \
# 0  1000.01   50365310          FP  07h29m25.85s  112.357708  -12d41m45.46s
# 1  1001.01   88863718          PC  08h10m19.31s  122.580465  -05d30m49.87s
# 2  1002.01  124709665          FP  06h58m54.47s  104.726966  -10d34m49.64s
# 3  1003.01  106997505          FP  07h22m14.39s  110.559945  -25d12m25.26s
# 4  1004.01  238597883          FP  08h08m42.77s  122.178195  -48d48m10.12s
#
#          dec  st_pmra  st_pmdec    pl_tranmid  ...  pl_trandurh   pl_trandep  \
# 0 -12.695960   -5.964    -0.076  2.459230e+06  ...      2.01722   656.886099
# 1  -5.513852   -4.956   -15.555  2.459988e+06  ...      3.16600  1286.000000
# 2 -10.580455   -1.462    -2.249  2.459225e+06  ...      1.40800  1500.000000
# 3 -25.207017   -0.939     1.640  2.458493e+06  ...      3.16700   383.410000
# ...

# %%
df.dropna(inplace=True)
print('Dataframe shape after dropping missing values:', df.shape, end='\n\n')
# Out:
# Dataframe shape after dropping missing values: (6589, 21)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# Remove columns that are likely not useful for SVM classification/regression
useless_cols = ['tid']  # Add/remove columns as needed
df_clean = df.drop(columns=useless_cols)

# Drop rows with missing values for simplicity (alternatively, use imputation)
df_clean = df_clean.dropna()

# Example: Let's predict 'tfopwg_disp' (classification) using the rest as features
X = df_clean.drop(columns=['tfopwg_disp'])
y = df_clean['tfopwg_disp']

# Encode categorical target if needed
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Hyperparameter optimization with GridSearchCV

param_grid = {
  'C': [0.1, 1, 10],
  'gamma': ['scale', 'auto'],
  'kernel': ['rbf', 'linear']
}

grid = GridSearchCV(SVC(), param_grid, cv=3, scoring='accuracy')
grid.fit(X_train, y_train)

print("Best parameters:", grid.best_params_)
print("Best cross-validation accuracy:", grid.best_score_)
print("Test set accuracy:", grid.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 22
#      19 y_encoded = le.fit_transform(y)
#      21 # Split data
# ---> 22 X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
#      24 # Hyperparameter optimization with GridSearchCV
#      26 param_grid = {
#      27   'C': [0.1, 1, 10],
#      28   'gamma': ['scale', 'auto'],
#      29   'kernel': ['rbf', 'linear']
#      30 }
#
# File ~/.conda/envs/exoplanet_classifier/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# ...
